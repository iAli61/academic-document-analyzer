# %%
import pandas as pd
from azureml.fsspec import AzureMachineLearningFileSystem
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(credential=DefaultAzureCredential())

uri = "azureml://subscriptions/45fb47bf-243f-43a8-b9a0-9329df91ed8b/resourcegroups/BEYOND_TEXT/workspaces/beyondtext/datastores/workspaceblobstore"

fs = AzureMachineLearningFileSystem(uri)
paths = fs.listdir('/azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings')

parquet_files = [file_info['name'] for file_info in paths if 'embeddings_' in file_info['name'] and file_info['name'].endswith('.parquet')]  
  
# Read all the parquet files and concatenate them into a single dataframe  
df = pd.concat((pd.read_parquet(fs.open(file)) for file in parquet_files))  
df
# Out:
# Found the config file in: /config.json
#                                   doc_id mtime  \
# 0   557179ec-3496-45f3-969d-8bd5b7373b05  None
# 1   3b1fb787-d86f-4284-a9b4-24d4baf23f10  None
# 2   f256555c-c761-47a6-a663-582f3878cc81  None
# 3   26396d95-0244-4529-8442-13563487a140  None
# 4   3fab55d3-7a9b-4a66-90f9-5bd70a7e9e1d  None
# ..                                   ...   ...
# 95  c2b32f72-e694-4be1-84ed-8f8cb36a0fd8  None
# 96  36c2a680-18e3-428c-9ce5-31468eac8173  None
# 97  cb432f2e-6c36-4e0e-a08f-ba989ae80684  None
# 98  3cb4e43f-a480-4d94-a5a9-73c0f79956fb  None
# 99  181e0120-cdc3-435b-98aa-be225ee46c85  None
#
#                                                  hash  \
# 0   7f0cffc5ab524e5e8ea3a7c4043065b1ad917df687716e...
# 1   29c84e58639b8d4e6fe2e708d4649aff4f07818020ab1c...
# 2   7e3e4de48afadfb3576a333b7a789542f89b9bd23d74b2...
# 3   eb9bac37bca22a240bdfdc9b393026540cdea68b434938...
# 4   389bb05f70a1c588e0e74bf81f1cb136163a5eee82628b...
# ...

# %%
df.iloc[0]
# Out:
# doc_id                       557179ec-3496-45f3-969d-8bd5b7373b05
# mtime                                                        None
# hash            7f0cffc5ab524e5e8ea3a7c4043065b1ad917df687716e...
# metadata        {"page_number": 1, "stats": {"tiktokens": 4, "...
# path_to_data                                       data_0.parquet
# index                                                           0
# is_local                                                     True
# Name: 0, dtype: object

# %%
parquet_files
# Out:
# ['azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_0.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_1.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_10.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_100.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_101.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_102.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_103.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_104.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_105.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_106.parquet',
#  'azureml/2b2f64d8-5470-43e6-bc55-c71a37acea5e/embeddings/embeddings_107.parquet',
# ...

# %%
import pandas as pd
from azureml.fsspec import AzureMachineLearningFileSystem
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(credential=DefaultAzureCredential())

uri = "azureml://subscriptions/45fb47bf-243f-43a8-b9a0-9329df91ed8b/resourcegroups/BEYOND_TEXT/workspaces/beyondtext/datastores/workspaceblobstore"

fs = AzureMachineLearningFileSystem(uri)
fs.download('azureml/849db637-ed7b-48a4-8f0c-445a0bb3752a/output_dir/4013758_Report/elements/table/page_6_Table_23444105707136.png', '.')
# Out:
# Found the config file in: /config.json

# %%
import pandas as pd
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(credential=DefaultAzureCredential())

uri = "azureml://subscriptions/45fb47bf-243f-43a8-b9a0-9329df91ed8b/resourcegroups/BEYOND_TEXT/workspaces/beyondtext/datastores/workspaceblobstore/paths/azureml/849db637-ed7b-48a4-8f0c-445a0bb3752a/output_dir/4013758_Report/elements/table/page_6_Table_23444105707136.png"

df = pd.read_csv(uri)
df

# %%
import pandas as pd
from azureml.fsspec import AzureMachineLearningFileSystem
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(credential=DefaultAzureCredential())

uri = "azureml://subscriptions/45fb47bf-243f-43a8-b9a0-9329df91ed8b/resourcegroups/BEYOND_TEXT/workspaces/beyondtext/datastores/raw_data"

fs = AzureMachineLearningFileSystem(uri)
# Out:
# Found the config file in: /config.json

# %%
fs.download('4013758_Report.pdf', '.')

# %%
import pandas as pd
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(credential=DefaultAzureCredential())

uri = "azureml://subscriptions/45fb47bf-243f-43a8-b9a0-9329df91ed8b/resourcegroups/BEYOND_TEXT/workspaces/beyondtext/datastores/raw_data/paths/4013758_Report.pdf"

df = pd.read_csv(uri)
df
