# %%
! az account set --subscription f804f2da-c27b-45ac-bf80-16d4d331776d

# %%
from azure.ai.ml.entities import Environment, BuildContext
from azure.identity import DefaultAzureCredential
from azure.ai.ml import MLClient

# Initialize workspace client
ml_client = MLClient.from_config(
    credential=DefaultAzureCredential()
)

env_docker_image = Environment(
    build=BuildContext(path="./docker"),
    name="doc-analyzer-env",
    version="9",
    description="Custom Environment for Document Analyzer",
)
ml_client.environments.create_or_update(env_docker_image)
# Out:
# Found the config file in: /home/alibina/repo/academic-document-analyzer/config.json
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# Cell In[9], line 16
#       6 ml_client = MLClient.from_config(
#       7     credential=DefaultAzureCredential()
#       8 )
#      10 env_docker_image = Environment(
#      11     build=BuildContext(path="./docker"),
#      12     name="doc-analyzer-env",
#      13     version="9",
#      14     description="Custom Environment for Document Analyzer",
#      15 )
# ---> 16 ml_client.environments.create_or_update(env_docker_image)
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_telemetry/activity.py:288, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     284     with tracer.start_as_current_span(ACTIVITY_SPAN):
#     285         with log_activity(
#     286             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     287         ):
# --> 288             return f(*args, **kwargs)
#     289 elif hasattr(logger, "package_logger"):
#     290     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/operations/_environment_operations.py:209, in EnvironmentOperations.create_or_update(self, environment)
#     207     log_and_raise_error(ex)
#     208 else:
# --> 209     raise ex
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/operations/_environment_operations.py:176, in EnvironmentOperations.create_or_update(self, environment)
#     160             return Environment._from_rest_object(env_rest_obj)
#     162     sas_uri = get_sas_uri_for_registry_asset(
#     163         service_client=self._service_client,
#     164         name=environment.name,
#    (...)
#     173         ),
#     174     )
# --> 176 environment = _check_and_upload_env_build_context(
#     177     environment=environment,
#     178     operations=self,
#     179     sas_uri=sas_uri,
#     180     show_progress=self._show_progress,
#     181 )
#     182 env_version_resource = environment._to_rest_object()
#     183 env_rest_obj = (
#     184     self._version_operations.begin_create_or_update(
#     185         name=environment.name,
#    (...)
#     200     )
#     201 )
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_artifacts/_artifact_utilities.py:538, in _check_and_upload_env_build_context(environment, operations, sas_uri, show_progress)
#     531 def _check_and_upload_env_build_context(
#     532     environment: Environment,
#     533     operations: "EnvironmentOperations",
#     534     sas_uri=None,
#     535     show_progress: bool = True,
#     536 ) -> Environment:
#     537     if environment.path:
# --> 538         uploaded_artifact = _upload_to_datastore(
#     539             operations._operation_scope,
#     540             operations._datastore_operation,
#     541             environment.path,
#     542             asset_name=environment.name,
#     543             asset_version=str(environment.version),
#     544             asset_hash=environment._upload_hash,
#     545             sas_uri=sas_uri,
#     546             artifact_type=ErrorTarget.ENVIRONMENT,
#     547             datastore_name=environment.datastore,
#     548             show_progress=show_progress,
#     549         )
#     550         if environment.build is not None:
#     551             # TODO: Depending on decision trailing "/" needs to stay or not. EMS requires it to be present
#     552             environment.build.path = str(uploaded_artifact.full_storage_path) + "/"
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_artifacts/_artifact_utilities.py:384, in _upload_to_datastore(operation_scope, datastore_operation, path, artifact_type, datastore_name, show_progress, asset_name, asset_version, asset_hash, ignore_file, sas_uri, blob_uri)
#     382 if not asset_hash:
#     383     asset_hash = get_object_hash(path, ignore_file)
# --> 384 artifact = upload_artifact(
#     385     str(path),
#     386     datastore_operation,
#     387     operation_scope,
#     388     datastore_name,
#     389     show_progress=show_progress,
#     390     asset_hash=asset_hash,
#     391     asset_name=asset_name,
#     392     asset_version=asset_version,
#     393     ignore_file=ignore_file,
#     394     sas_uri=sas_uri,
#     395 )
#     396 if blob_uri:
#     397     artifact.storage_account_url = blob_uri
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_artifacts/_artifact_utilities.py:243, in upload_artifact(local_path, datastore_operation, operation_scope, datastore_name, asset_hash, show_progress, asset_name, asset_version, ignore_file, sas_uri)
#     240     datastore_info = get_datastore_info(datastore_operation, datastore_name)
#     241     storage_client = get_storage_client(**datastore_info)
# --> 243 artifact_info = storage_client.upload(
#     244     local_path,
#     245     asset_hash=asset_hash,
#     246     show_progress=show_progress,
#     247     name=asset_name,
#     248     version=asset_version,
#     249     ignore_file=ignore_file,
#     250 )
#     252 artifact = ArtifactStorageInfo(
#     253     name=artifact_info["name"],
#     254     version=artifact_info["version"],
#    (...)
#     262     is_file=Path(local_path).is_file(),
#     263 )
#     264 return artifact
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_artifacts/_blob_storage_helper.py:122, in BlobStorageClient.upload(self, source, name, version, ignore_file, asset_hash, show_progress)
#     120 # start upload
#     121 if os.path.isdir(source):
# --> 122     upload_directory(
#     123         storage_client=self,
#     124         source=source,
#     125         dest=asset_id,
#     126         msg=msg,
#     127         show_progress=show_progress,
#     128         ignore_file=ignore_file,
#     129     )
#     130 else:
#     131     self.indicator_file = dest
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_utils/_asset_utils.py:711, in upload_directory(storage_client, source, dest, msg, show_progress, ignore_file)
#     703 if (
#     704     type(storage_client).__name__ == BLOB_STORAGE_CLIENT_NAME
#     705 ):  # Only for Gen2StorageClient, Blob Storage doesn't have true directories
#    (...)
#     708     # file in the directory is designated as the file where the confirmation metadata
#     709     # will be added at the end of the upload.
#     710     storage_client.indicator_file = upload_paths[0][1]
# --> 711     storage_client.check_blob_exists()
#     713 # Submit paths to workers for upload
#     714 num_cores = int(cpu_count()) * PROCESSES_PER_CORE
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_artifacts/_blob_storage_helper.py:226, in BlobStorageClient.check_blob_exists(self)
#     215     msg = (
#     216         "You don't have permission to alter this storage account. "
#     217         "Ensure that you have been assigned both Storage Blob Data Reader "
#     218         "and Storage Blob Data Contributor roles."
#     219     )
#     220     raise ValidationException(
#     221         message=msg,
#     222         no_personal_data_message=msg,
#     223         target=ErrorTarget.ARTIFACT,
#     224         error_category=ErrorCategory.USER_ERROR,
#     225     ) from e
# --> 226 raise e
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_artifacts/_blob_storage_helper.py:184, in BlobStorageClient.check_blob_exists(self)
#     182         exception_with_documentation.__traceback__ = e.exc_traceback
#     183         raise exception_with_documentation from e
# --> 184     raise e
#     186 metadata = properties.get("metadata")
#     188 # first check legacy folder's metadata to see if artifact is stored there
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/ai/ml/_artifacts/_blob_storage_helper.py:175, in BlobStorageClient.check_blob_exists(self)
#     172 legacy_blob_client = self.container_client.get_blob_client(blob=legacy_indicator_file)
#     174 try:
# --> 175     properties = blob_client.get_blob_properties()
#     176 except HttpResponseError as e:
#     177     if e.error_code == KEY_AUTHENTICATION_ERROR_CODE:  # pylint: disable=no-member
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/core/tracing/decorator.py:116, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     114 for key, value in func_tracing_attributes.items():
#     115     span.add_attribute(key, value)
# --> 116 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/storage/blob/_blob_client.py:1091, in BlobClient.get_blob_properties(self, **kwargs)
#    1081     blob_props = cast(BlobProperties, self._client.blob.get_properties(
#    1082         timeout=kwargs.pop('timeout', None),
#    1083         version_id=version_id,
#    (...)
#    1088         cpk_info=cpk_info,
#    1089         **kwargs))
#    1090 except HttpResponseError as error:
# -> 1091     process_storage_error(error)
#    1092 blob_props.name = self.blob_name
#    1093 if isinstance(blob_props, BlobProperties):
#
# File ~/miniconda3/envs/ai_scientist/lib/python3.11/site-packages/azure/storage/blob/_shared/response_handlers.py:186, in process_storage_error(storage_error)
#     183 error.args = (error.message,)
#     184 try:
#     185     # `from None` prevents us from double printing the exception (suppresses generated layer error context)
# --> 186     exec("raise error from None")   # pylint: disable=exec-used # nosec
#     187 except SyntaxError as exc:
#     188     raise error from exc
#
# File <string>:1
#
# HttpResponseError: Operation returned an invalid status 'This request is not authorized to perform this operation.'
# ErrorCode:AuthorizationFailure
